# %%
import pandas as pd
import numpy as np

# %%
respOutcomes = pd.read_csv("/Users/keerthyrangan/Downloads/Sci4GAData/HDPulse_data_export (1).csv")
respOutcomes
# Out:
#                 County   FIPS Age-Adjusted Death Rate(†) - deaths per 100,000  \
# 0       Berrien County  13019                                           108.2
# 1        Echols County  13101                                           102.4
# 2    Jeff Davis County  13161                                            97.4
# 3         Upson County  13293                                            96.6
# 4     Chattooga County  13055                                            94.9
# ..                 ...    ...                                             ...
# 154    Glascock County  13125                                              *
# 155     Quitman County  13239                                              *
# 156     Stewart County  13259                                              *
# 157  Taliaferro County  13265                                              *
# 158     Webster County  13307                                              *
#
# ...

# %%
respOutcomes["Average Annual Infection Count"] = pd.to_numeric(respOutcomes["Average Annual Count"], errors = "coerce")
respOutcomes.dropna()
# Out:
#                 County   FIPS  \
# 0       Berrien County  13019
# 1        Echols County  13101
# 2    Jeff Davis County  13161
# 3         Upson County  13293
# 4     Chattooga County  13055
# ..                 ...    ...
# 145     Fayette County  13113
# 146        Cobb County  13067
# 147      Greene County  13133
# 148      Fulton County  13121
# 149      DeKalb County  13089
#
#      Age-Adjusted Death Rate(†) - deaths per 100,000  \
# 0                                              108.2
# 1                                              102.4
# 2                                               97.4
# 3                                               96.6
# 4                                               94.9
# ..                                               ...
# 145                                             25.7
# 146                                             25.5
# 147                                             24.8
# 148                                             24.0
# ...

# %%
respOutcomes.to_csv('/Users/keerthyrangan/Downloads/Sci4GAData/respOutcomes.csv', index=False)
